# %%
import pandas as pd
import numpy as np
import unicodedata

Filename="EnglishRead.txt"

with open('EnglishRead.txt', 'r') as file:
    data = file.read().replace('\n', '')

import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# remove punctuation
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

remove_punctuation(data)
# Out:
# 'the taliban have captured three regional capitals in afghanistan as they continue to make sweeping territorial gains in the country they seized control of the key northern city of kunduz on sunday as well as sarepul and taloqan it means five regional capitals have fallen to the militants since friday with kunduz being their most important gain this year the city is well connected to other areas including the capital kabul violence has escalated across afghanistan after us and other international forces began to withdraw their troops from the country following years of military operations taliban militants have made rapid advances in recent weeks having captured large swathes of the countryside they are now targeting key towns and cities the three northern cities fell to taliban control within hours of each other on sunday with one resident in kunduz describing the situation astotal chaos the afghan government meanwhile said its forces were fighting to retake key installations heavy fighting has also been reported in herat in the west and in the southern cities of kandahar and lashkar gah thousands of civilians have been displaced this year families including babies and young children have been sheltering in a school in the northeastern city of asadabadmany bombs were dropped on our village the taliban came and destroyed everything we were helpless and had to leave our houses our children and ourselves are sleeping on the ground in dire conditions gul naaz told afpthere was firing one of my sevenyearold daughters went out during that fighting and disappeared i dont know if she is alive or dead another displaced resident said the us has intensified its air strikes on taliban positions with afghan military officials saying militants have been killed but the taliban say the air strikes hit two hospitals and a school in the city of lashkar gah neither claim has been independently verified the us embassy in afghanistan condemned the talibansviolent new offensive against afghan cities saying the groups actions toforcibly impose its rule are unacceptablethey demonstrate wanton disregard for the welfare and rights of civilians and will worsen this countrys humanitarian crisis it said in a statement a big change on the battlefield by khalil noori bbc news kabul this attack on a number of strategic cities and their fall to the taliban was unprecedented but as the deadline for the full withdrawal of foreign forces approached a big change on the battlefield was expected now it is time for the afghan government to prove that its wellequipped forces strong are able to retake the lost areas it would be difficult for the taliban to hold kunduz but for several weeks the group has kept control of commercial centres important for trade with iran and pakistan the populations in cities taken by the taliban are paying the price of war having lost loved ones or property they are having to leave their homes fearing the launch of a government operation to retake the cities peace talks with the taliban in doha are deadlocked if the process resumes from now on both sides will be trying to control the larger area to justify a greater share of power if they agree on a transitional government the importance of kunduz the seizure of kunduz is the most significant gain for the taliban since they launched their offensive in may the city home to people is considered a gateway to the countrys mineralrich northern provinces and its location makes it strategically important as there are highways connecting kunduz to other major cities including kabul and the province shares a border with tajikistan that border is used for the smuggling of afghan opium and heroin to central asia which then finds its way to europe controlling kunduz means controlling one of the most important drug smuggling routes in the region it also holds symbolic significance for the taliban because it was a key northern stronghold before the militants captured the city in and again in but have ...

# %%
# Stop word removaland function for tokenization

import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
# remove stopwords function
def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    return filtered_text

data_token = remove_stopwords(data)
#print(data_token)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Stemming function  
# Lemmatization
 
from nltk.stem import PorterStemmer
ps =PorterStemmer()
for w in data_token:
    rootWord=ps.stem(w)
    #print(rootWord)

# %%
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()
tokenization = nltk.word_tokenize(data)

for w in tokenization:
  print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for have is have
# Lemma for captured is captured
# Lemma for three is three
# Lemma for regional is regional
# Lemma for capitals is capital
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for as is a
# Lemma for they is they
# Lemma for continue is continue
# Lemma for to is to
# Lemma for make is make
# Lemma for sweeping is sweeping
# Lemma for territorial is territorial
# Lemma for gains is gain
# Lemma for in is in
# Lemma for the is the
# Lemma for country is country
# Lemma for . is .
# Lemma for they is they
# Lemma for seized is seized
# Lemma for control is control
# Lemma for of is of
# Lemma for the is the
# Lemma for key is key
# Lemma for northern is northern
# Lemma for city is city
# Lemma for of is of
# Lemma for kunduz is kunduz
# Lemma for on is on
# Lemma for sunday is sunday
# Lemma for . is .
# Lemma for as is a
# Lemma for well is well
# Lemma for as is a
# Lemma for sar.e.pul is sar.e.pul
# Lemma for and is and
# Lemma for taloqan is taloqan
# Lemma for . is .
# Lemma for it is it
# Lemma for means is mean
# Lemma for five is five
# Lemma for regional is regional
# Lemma for capitals is capital
# Lemma for have is have
# Lemma for fallen is fallen
# Lemma for to is to
# Lemma for the is the
# Lemma for militants is militant
# Lemma for since is since
# Lemma for friday is friday
# Lemma for . is .
# Lemma for with is with
# Lemma for kunduz is kunduz
# Lemma for being is being
# Lemma for their is their
# Lemma for most is most
# Lemma for important is important
# Lemma for gain is gain
# Lemma for this is this
# Lemma for year is year
# Lemma for . is .
# Lemma for the is the
# Lemma for city is city
# Lemma for is is is
# Lemma for well is well
# Lemma for connected is connected
# Lemma for to is to
# Lemma for other is other
# Lemma for areas is area
# Lemma for . is .
# Lemma for including is including
# Lemma for the is the
# Lemma for capital is capital
# Lemma for kabul is kabul
# Lemma for . is .
# Lemma for violence is violence
# Lemma for has is ha
# Lemma for escalated is escalated
# Lemma for across is across
# Lemma for afghanistan is afghanistan
# Lemma for after is after
# Lemma for us is u
# Lemma for and is and
# Lemma for other is other
# Lemma for international is international
# Lemma for forces is force
# Lemma for began is began
# Lemma for to is to
# Lemma for withdraw is withdraw
# Lemma for their is their
# Lemma for troops is troop
# Lemma for from is from
# Lemma for the is the
# Lemma for country is country
# Lemma for . is .
# Lemma for following is following
# Lemma for years is year
# Lemma for of is of
# Lemma for military is military
# Lemma for operations is operation
# Lemma for . is .
# Lemma for taliban is taliban
# Lemma for militants is militant
# Lemma for have is have
# Lemma for made is made
# Lemma for rapid is rapid
# Lemma for advances is advance
# Lemma for in is in
# Lemma for recent is recent
# Lemma for weeks is week
# Lemma for . is .
# Lemma for having is having
# Lemma for captured is captured
# Lemma for large is large
# Lemma for swathes is swathe
# Lemma for of is of
# Lemma for the is the
# Lemma for countryside is countryside
# Lemma for . is .
# Lemma for they is they
# Lemma for are is are
# Lemma for now is now
# Lemma for targeting is targeting
# Lemma for key is key
# Lemma for towns is town
# Lemma for and is and
# Lemma for cities is city
# Lemma for . is .
# Lemma for the is the
# Lemma for three is three
# Lemma for northern is northern
# Lemma for cities is city
# Lemma for fell is fell
# Lemma for to is to
# Lemma for taliban is taliban
# Lemma for control is control
# Lemma for within is within
# Lemma for hours is hour
# Lemma for of is of
# Lemma for each is each
# Lemma for other is other
# Lemma for on is on
# Lemma for sunday is sunday
# Lemma for . is .
# Lemma for with is with
# Lemma for one is one
# Lemma for resident is resident
# Lemma for in is in
# Lemma for kunduz is kunduz
# Lemma for describing is describing
# Lemma for the is the
# Lemma for situation is situation
# Lemma for as.total is as.total
# Lemma for chaos is chaos
# Lemma for . is .
# Lemma for the is the
# Lemma for afghan is afghan
# Lemma for government is government
# Lemma for . is .
# Lemma for meanwhile is meanwhile
# Lemma for . is .
# Lemma for said is said
# Lemma for its is it
# Lemma for forces is force
# Lemma for were is were
# Lemma for fighting is fighting
# Lemma for to is to
# Lemma for retake is retake
# Lemma for key is key
# Lemma for installations is installation
# Lemma for . is .
# Lemma for heavy is heavy
# Lemma for fighting is fighting
# Lemma for has is ha
# Lemma for also is also
# Lemma for been is been
# Lemma for reported is reported
# Lemma for in is in
# Lemma for herat is herat
# Lemma for in is in
# Lemma for the is the
# Lemma for west is west
# Lemma for . is .
# Lemma for and is and
# Lemma for in is in
# Lemma for the is the
# Lemma for southern is southern
# Lemma for cities is city
# Lemma for of is of
# Lemma for kandahar is kandahar
# Lemma for and is and
# Lemma for lashkar is lashkar
# Lemma for gah is gah
# Lemma for . is .
# Lemma for thousands is thousand
# Lemma for of is of
# Lemma for civilians is civilian
# Lemma for have is have
# Lemma for been is been
# Lemma for displaced is displaced
# Lemma for this is this
# Lemma for year is year
# Lemma for . is .
# Lemma for families is family
# Lemma for . is .
# Lemma for including is including
# Lemma for babies is baby
# Lemma for and is and
# Lemma for young is young
# Lemma for children is child
# Lemma for . is .
# Lemma for have is have
# Lemma for been is been
# Lemma for sheltering is sheltering
# Lemma for in is in
# Lemma for a is a
# Lemma for school is school
# Lemma for in is in
# Lemma for the is the
# Lemma for north.eastern is north.eastern
# Lemma for city is city
# Lemma for of is of
# Lemma for asadabad.many is asadabad.many
# Lemma for bombs is bomb
# Lemma for were is were
# Lemma for dropped is dropped
# Lemma for on is on
# Lemma for our is our
# Lemma for village is village
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for came is came
# Lemma for and is and
# Lemma for destroyed is destroyed
# Lemma for everything is everything
# Lemma for . is .
# Lemma for we is we
# Lemma for were is were
# Lemma for helpless is helpless
# Lemma for and is and
# Lemma for had is had
# Lemma for to is to
# Lemma for leave is leave
# Lemma for our is our
# Lemma for houses is house
# Lemma for . is .
# Lemma for our is our
# Lemma for children is child
# Lemma for and is and
# Lemma for ourselves is ourselves
# Lemma for are is are
# Lemma for sleeping is sleeping
# Lemma for on is on
# Lemma for the is the
# Lemma for ground is ground
# Lemma for in is in
# Lemma for dire is dire
# Lemma for conditions is condition
# Lemma for . is .
# Lemma for gul is gul
# Lemma for naaz is naaz
# Lemma for told is told
# Lemma for afp.there is afp.there
# Lemma for was is wa
# Lemma for firing is firing
# Lemma for . is .
# Lemma for one is one
# Lemma for of is of
# Lemma for my is my
# Lemma for seven.year.old is seven.year.old
# Lemma for daughters is daughter
# Lemma for went is went
# Lemma for out is out
# Lemma for during is during
# Lemma for that is that
# Lemma for fighting is fighting
# Lemma for and is and
# Lemma for disappeared is disappeared
# Lemma for . is .
# Lemma for i is i
# Lemma for don.t is don.t
# Lemma for know is know
# Lemma for if is if
# Lemma for she is she
# Lemma for is is is
# Lemma for alive is alive
# Lemma for or is or
# Lemma for dead is dead
# Lemma for . is .
# Lemma for another is another
# Lemma for displaced is displaced
# Lemma for resident is resident
# Lemma for said is said
# Lemma for . is .
# Lemma for the is the
# Lemma for us is u
# Lemma for has is ha
# Lemma for intensified is intensified
# Lemma for its is it
# Lemma for air is air
# Lemma for strikes is strike
# Lemma for on is on
# Lemma for taliban is taliban
# Lemma for positions is position
# Lemma for . is .
# Lemma for with is with
# Lemma for afghan is afghan
# Lemma for military is military
# Lemma for officials is official
# Lemma for saying is saying
# Lemma for militants is militant
# Lemma for have is have
# Lemma for been is been
# Lemma for killed is killed
# Lemma for . is .
# Lemma for but is but
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for say is say
# Lemma for the is the
# Lemma for air is air
# Lemma for strikes is strike
# Lemma for hit is hit
# Lemma for two is two
# Lemma for hospitals is hospital
# Lemma for and is and
# Lemma for a is a
# Lemma for school is school
# Lemma for in is in
# Lemma for the is the
# Lemma for city is city
# Lemma for of is of
# Lemma for lashkar is lashkar
# Lemma for gah is gah
# Lemma for . is .
# Lemma for neither is neither
# Lemma for claim is claim
# Lemma for has is ha
# Lemma for been is been
# Lemma for independently is independently
# Lemma for verified is verified
# Lemma for . is .
# Lemma for the is the
# Lemma for us is u
# Lemma for embassy is embassy
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for condemned is condemned
# Lemma for the is the
# Lemma for taliban.s.violent is taliban.s.violent
# Lemma for new is new
# Lemma for offensive is offensive
# Lemma for against is against
# Lemma for afghan is afghan
# Lemma for cities is city
# Lemma for . is .
# Lemma for saying is saying
# Lemma for the is the
# Lemma for group.s is group.s
# Lemma for actions is action
# Lemma for to.forcibly is to.forcibly
# Lemma for impose is impose
# Lemma for its is it
# Lemma for rule is rule
# Lemma for are is are
# Lemma for unacceptable.they is unacceptable.they
# Lemma for demonstrate is demonstrate
# Lemma for wanton is wanton
# Lemma for disregard is disregard
# Lemma for for is for
# Lemma for the is the
# Lemma for welfare is welfare
# Lemma for and is and
# Lemma for rights is right
# Lemma for of is of
# Lemma for civilians is civilian
# Lemma for and is and
# Lemma for will is will
# Lemma for worsen is worsen
# Lemma for this is this
# Lemma for country.s is country.s
# Lemma for humanitarian is humanitarian
# Lemma for crisis is crisis
# Lemma for . is .
# Lemma for it is it
# Lemma for said is said
# Lemma for in is in
# Lemma for a is a
# Lemma for statement is statement
# Lemma for . is .
# Lemma for a is a
# Lemma for big is big
# Lemma for change is change
# Lemma for on is on
# Lemma for the is the
# Lemma for battlefield is battlefield
# Lemma for by is by
# Lemma for khalil is khalil
# Lemma for noori is noori
# Lemma for . is .
# Lemma for bbc is bbc
# Lemma for news is news
# Lemma for . is .
# Lemma for kabul is kabul
# Lemma for this is this
# Lemma for attack is attack
# Lemma for on is on
# Lemma for a is a
# Lemma for number is number
# Lemma for of is of
# Lemma for strategic is strategic
# Lemma for cities is city
# Lemma for and is and
# Lemma for their is their
# Lemma for fall is fall
# Lemma for to is to
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for was is wa
# Lemma for unprecedented is unprecedented
# Lemma for . is .
# Lemma for but is but
# Lemma for as is a
# Lemma for the is the
# Lemma for deadline is deadline
# Lemma for for is for
# Lemma for the is the
# Lemma for full is full
# Lemma for withdrawal is withdrawal
# Lemma for of is of
# Lemma for foreign is foreign
# Lemma for forces is force
# Lemma for approached is approached
# Lemma for . is .
# Lemma for a is a
# Lemma for big is big
# Lemma for change is change
# Lemma for on is on
# Lemma for the is the
# Lemma for battlefield is battlefield
# Lemma for was is wa
# Lemma for expected is expected
# Lemma for . is .
# Lemma for now is now
# Lemma for it is it
# Lemma for is is is
# Lemma for time is time
# Lemma for for is for
# Lemma for the is the
# Lemma for afghan is afghan
# Lemma for government is government
# Lemma for to is to
# Lemma for prove is prove
# Lemma for that is that
# Lemma for its is it
# Lemma for well.equipped is well.equipped
# Lemma for forces is force
# Lemma for . is .
# Lemma for strong is strong
# Lemma for . is .
# Lemma for are is are
# Lemma for able is able
# Lemma for to is to
# Lemma for retake is retake
# Lemma for the is the
# Lemma for lost is lost
# Lemma for areas is area
# Lemma for . is .
# Lemma for it is it
# Lemma for would is would
# Lemma for be is be
# Lemma for difficult is difficult
# Lemma for for is for
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for to is to
# Lemma for hold is hold
# Lemma for kunduz is kunduz
# Lemma for . is .
# Lemma for but is but
# Lemma for for is for
# Lemma for several is several
# Lemma for weeks is week
# Lemma for the is the
# Lemma for group is group
# Lemma for has is ha
# Lemma for kept is kept
# Lemma for control is control
# Lemma for of is of
# Lemma for commercial is commercial
# Lemma for centres is centre
# Lemma for important is important
# Lemma for for is for
# Lemma for trade is trade
# Lemma for with is with
# Lemma for iran is iran
# Lemma for and is and
# Lemma for pakistan is pakistan
# Lemma for . is .
# Lemma for the is the
# Lemma for populations is population
# Lemma for in is in
# Lemma for cities is city
# Lemma for taken is taken
# Lemma for by is by
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for are is are
# Lemma for paying is paying
# Lemma for the is the
# Lemma for price is price
# Lemma for of is of
# Lemma for war is war
# Lemma for . is .
# Lemma for having is having
# Lemma for lost is lost
# Lemma for loved is loved
# Lemma for ones is one
# Lemma for or is or
# Lemma for property is property
# Lemma for . is .
# Lemma for they is they
# Lemma for are is are
# Lemma for having is having
# Lemma for to is to
# Lemma for leave is leave
# Lemma for their is their
# Lemma for homes is home
# Lemma for . is .
# Lemma for fearing is fearing
# Lemma for the is the
# Lemma for launch is launch
# Lemma for of is of
# Lemma for a is a
# Lemma for government is government
# Lemma for operation is operation
# Lemma for to is to
# Lemma for retake is retake
# Lemma for the is the
# Lemma for cities is city
# Lemma for . is .
# Lemma for peace is peace
# Lemma for talks is talk
# Lemma for with is with
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for in is in
# Lemma for doha is doha
# Lemma for are is are
# Lemma for deadlocked is deadlocked
# Lemma for . is .
# Lemma for if is if
# Lemma for the is the
# Lemma for process is process
# Lemma for resumes is resume
# Lemma for . is .
# Lemma for from is from
# Lemma for now is now
# Lemma for on is on
# Lemma for both is both
# Lemma for sides is side
# Lemma for will is will
# Lemma for be is be
# Lemma for trying is trying
# Lemma for to is to
# Lemma for control is control
# Lemma for the is the
# Lemma for larger is larger
# Lemma for area is area
# Lemma for to is to
# Lemma for justify is justify
# Lemma for a is a
# Lemma for greater is greater
# Lemma for share is share
# Lemma for of is of
# Lemma for power is power
# Lemma for . is .
# Lemma for if is if
# Lemma for they is they
# Lemma for agree is agree
# Lemma for on is on
# Lemma for a is a
# Lemma for transitional is transitional
# Lemma for government is government
# Lemma for . is .
# Lemma for the is the
# Lemma for importance is importance
# Lemma for of is of
# Lemma for kunduz is kunduz
# Lemma for the is the
# Lemma for seizure is seizure
# Lemma for of is of
# Lemma for kunduz is kunduz
# Lemma for is is is
# Lemma for the is the
# Lemma for most is most
# Lemma for significant is significant
# Lemma for gain is gain
# Lemma for for is for
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for since is since
# Lemma for they is they
# Lemma for launched is launched
# Lemma for their is their
# Lemma for offensive is offensive
# Lemma for in is in
# Lemma for may is may
# Lemma for . is .
# Lemma for the is the
# Lemma for city is city
# Lemma for . is .
# Lemma for home is home
# Lemma for to is to
# Lemma for . is .
# Lemma for people is people
# Lemma for . is .
# Lemma for is is is
# Lemma for considered is considered
# Lemma for a is a
# Lemma for gateway is gateway
# Lemma for to is to
# Lemma for the is the
# Lemma for country.s is country.s
# Lemma for mineral.rich is mineral.rich
# Lemma for northern is northern
# Lemma for provinces is province
# Lemma for . is .
# Lemma for and is and
# Lemma for its is it
# Lemma for location is location
# Lemma for makes is make
# Lemma for it is it
# Lemma for strategically is strategically
# Lemma for important is important
# Lemma for as is a
# Lemma for there is there
# Lemma for are is are
# Lemma for highways is highway
# Lemma for connecting is connecting
# Lemma for kunduz is kunduz
# Lemma for to is to
# Lemma for other is other
# Lemma for major is major
# Lemma for cities is city
# Lemma for . is .
# Lemma for including is including
# Lemma for kabul is kabul
# Lemma for . is .
# Lemma for and is and
# Lemma for the is the
# Lemma for province is province
# Lemma for shares is share
# Lemma for a is a
# Lemma for border is border
# Lemma for with is with
# Lemma for tajikistan is tajikistan
# Lemma for . is .
# Lemma for that is that
# Lemma for border is border
# Lemma for is is is
# Lemma for used is used
# Lemma for for is for
# Lemma for the is the
# Lemma for smuggling is smuggling
# Lemma for of is of
# Lemma for afghan is afghan
# Lemma for opium is opium
# Lemma for and is and
# Lemma for heroin is heroin
# Lemma for to is to
# Lemma for central is central
# Lemma for asia is asia
# Lemma for . is .
# Lemma for which is which
# Lemma for then is then
# Lemma for finds is find
# Lemma for its is it
# Lemma for way is way
# Lemma for to is to
# Lemma for europe is europe
# Lemma for . is .
# Lemma for controlling is controlling
# Lemma for kunduz is kunduz
# Lemma for means is mean
# Lemma for controlling is controlling
# Lemma for one is one
# Lemma for of is of
# Lemma for the is the
# Lemma for most is most
# Lemma for important is important
# Lemma for drug is drug
# Lemma for smuggling is smuggling
# Lemma for routes is route
# Lemma for in is in
# Lemma for the is the
# Lemma for region is region
# Lemma for . is .
# Lemma for it is it
# Lemma for also is also
# Lemma for holds is hold
# Lemma for symbolic is symbolic
# Lemma for significance is significance
# Lemma for for is for
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for because is because
# Lemma for it is it
# Lemma for was is wa
# Lemma for a is a
# Lemma for key is key
# Lemma for northern is northern
# Lemma for stronghold is stronghold
# Lemma for before is before
# Lemma for . is .
# Lemma for the is the
# Lemma for militants is militant
# Lemma for captured is captured
# Lemma for the is the
# Lemma for city is city
# Lemma for in is in
# Lemma for and is and
# Lemma for again is again
# Lemma for in is in
# Lemma for but is but
# Lemma for have is have
# Lemma for never is never
# Lemma for been is been
# Lemma for able is able
# Lemma for to is to
# Lemma for hold is hold
# Lemma for it is it
# Lemma for for is for
# Lemma for long is long
# Lemma for . is .
# Lemma for is is is
# Lemma for afghanistan is afghanistan
# Lemma for being is being
# Lemma for left.friendless is left.friendless
# Lemma for . is .
# Lemma for by is by
# Lemma for paul is paul
# Lemma for adams is adam
# Lemma for . is .
# Lemma for bbc is bbc
# Lemma for diplomatic is diplomatic
# Lemma for correspondent is correspondent
# Lemma for former is former
# Lemma for british is british
# Lemma for gen is gen
# Lemma for sir is sir
# Lemma for richard is richard
# Lemma for barrons is barrons
# Lemma for says is say
# Lemma for there is there
# Lemma for is is is
# Lemma for a is a
# Lemma for danger is danger
# Lemma for of is of
# Lemma for afghanistan is afghanistan
# Lemma for feeling.friendless is feeling.friendless
# Lemma for . is .
# Lemma for in is in
# Lemma for the is the
# Lemma for wake is wake
# Lemma for of is of
# Lemma for recent is recent
# Lemma for battlefield is battlefield
# Lemma for defeats is defeat
# Lemma for and is and
# Lemma for the is the
# Lemma for possible is possible
# Lemma for withdrawal is withdrawal
# Lemma for of is of
# Lemma for diplomats is diplomat
# Lemma for and is and
# Lemma for contractors is contractor
# Lemma for from is from
# Lemma for kabul is kabul
# Lemma for if is if
# Lemma for things is thing
# Lemma for get is get
# Lemma for worse is worse
# Lemma for . is .
# Lemma for it is it
# Lemma for is is is
# Lemma for much is much
# Lemma for too is too
# Lemma for early is early
# Lemma for to is to
# Lemma for speculate is speculate
# Lemma for about is about
# Lemma for a is a
# Lemma for saigon.style is saigon.style
# Lemma for withdrawal is withdrawal
# Lemma for from is from
# Lemma for the is the
# Lemma for capital is capital
# Lemma for . is .
# Lemma for echoing is echoing
# Lemma for the is the
# Lemma for way is way
# Lemma for the is the
# Lemma for americans is american
# Lemma for hastily is hastily
# Lemma for left is left
# Lemma for vietnam is vietnam
# Lemma for in is in
# Lemma for the is the
# Lemma for final is final
# Lemma for act is act
# Lemma for of is of
# Lemma for the is the
# Lemma for war is war
# Lemma for there is there
# Lemma for . is .
# Lemma for in is in
# Lemma for . is .
# Lemma for but is but
# Lemma for in is in
# Lemma for recent is recent
# Lemma for days is day
# Lemma for . is .
# Lemma for british is british
# Lemma for and is and
# Lemma for american is american
# Lemma for calls is call
# Lemma for for is for
# Lemma for their is their
# Lemma for nationals is national
# Lemma for to is to
# Lemma for leave is leave
# Lemma for the is the
# Lemma for country is country
# Lemma for threaten is threaten
# Lemma for to is to
# Lemma for create is create
# Lemma for a is a
# Lemma for dangerous is dangerous
# Lemma for narrative is narrative
# Lemma for . is .
# Lemma for it is it
# Lemma for is is is
# Lemma for something is something
# Lemma for that is that
# Lemma for western is western
# Lemma for military is military
# Lemma for planners is planner
# Lemma for have is have
# Lemma for been is been
# Lemma for worried is worried
# Lemma for about is about
# Lemma for for is for
# Lemma for some is some
# Lemma for time is time
# Lemma for . is .
# Lemma for following is following
# Lemma for us is u
# Lemma for president is president
# Lemma for joe is joe
# Lemma for biden.s is biden.s
# Lemma for decision is decision
# Lemma for . is .
# Lemma for in is in
# Lemma for april is april
# Lemma for . is .
# Lemma for to is to
# Lemma for withdraw is withdraw
# Lemma for american is american
# Lemma for forces is force
# Lemma for by is by
# Lemma for september is september
# Lemma for . is .
# Lemma for in is in
# Lemma for june is june
# Lemma for . is .
# Lemma for classified is classified
# Lemma for uk is uk
# Lemma for ministry is ministry
# Lemma for of is of
# Lemma for defence is defence
# Lemma for documents is document
# Lemma for were is were
# Lemma for found is found
# Lemma for at is at
# Lemma for a is a
# Lemma for canterbury is canterbury
# Lemma for bus is bus
# Lemma for stop is stop
# Lemma for by is by
# Lemma for a is a
# Lemma for member is member
# Lemma for of is of
# Lemma for the is the
# Lemma for public is public
# Lemma for . is .
# Lemma for one is one
# Lemma for of is of
# Lemma for them is them
# Lemma for voiced is voiced
# Lemma for just is just
# Lemma for this is this
# Lemma for concern is concern
# Lemma for . is .
# Lemma for speaking is speaking
# Lemma for about is about
# Lemma for the is the
# Lemma for need is need
# Lemma for to is to
# Lemma for counter is counter
# Lemma for an.abandonment is an.abandonment
# Lemma for narrative is narrative
# Lemma for . is .
# Lemma for in is in
# Lemma for afghanistan.precise is afghanistan.precise
# Lemma for language is language
# Lemma for may is may
# Lemma for be is be
# Lemma for needed is needed
# Lemma for . is .
# Lemma for it is it
# Lemma for said.to is said.to
# Lemma for avoid is avoid
# Lemma for misunderstandings is misunderstanding
# Lemma for about.retrograde is about.retrograde
# Lemma for to is to
# Lemma for zero is zero
# Lemma for . is .
# Lemma for vs is v
# Lemma for normal is normal
# Lemma for diplomatic is diplomatic
# Lemma for .including is .including
# Lemma for military is military
# Lemma for . is .
# Lemma for representation.retrograde is representation.retrograde
# Lemma for to is to
# Lemma for zero is zero
# Lemma for . is .
# Lemma for is is is
# Lemma for the is the
# Lemma for peculiar is peculiar
# Lemma for euphemism is euphemism
# Lemma for used is used
# Lemma for to is to
# Lemma for describe is describe
# Lemma for the is the
# Lemma for withdrawal is withdrawal
# Lemma for process is process
# Lemma for now is now
# Lemma for in is in
# Lemma for its is it
# Lemma for final is final
# Lemma for weeks is week
# Lemma for . is .
# Lemma for in is in
# Lemma for other is other
# Lemma for words is word
# Lemma for . is .
# Lemma for planners is planner
# Lemma for were is were
# Lemma for only is only
# Lemma for too is too
# Lemma for aware is aware
# Lemma for of is of
# Lemma for creating is creating
# Lemma for the is the
# Lemma for dangerous is dangerous
# Lemma for impression is impression
# Lemma for that is that
# Lemma for afghanistan is afghanistan
# Lemma for might is might
# Lemma for indeed is indeed
# Lemma for be is be
# Lemma for left.friendless is left.friendless
# Lemma for . is .
# Lemma for that is that
# Lemma for is is is
# Lemma for not is not
# Lemma for yet is yet
# Lemma for the is the
# Lemma for case is case
# Lemma for . is .
# Lemma for american is american
# Lemma for air is air
# Lemma for strikes is strike
# Lemma for are is are
# Lemma for still is still
# Lemma for being is being
# Lemma for used is used
# Lemma for in is in
# Lemma for an is an
# Lemma for attempt is attempt
# Lemma for to is to
# Lemma for halt is halt
# Lemma for the is the
# Lemma for taliban.s is taliban.s
# Lemma for advances is advance
# Lemma for . is .
# Lemma for britain is britain
# Lemma for and is and
# Lemma for the is the
# Lemma for us is u
# Lemma for will is will
# Lemma for doubtless is doubtless
# Lemma for have is have
# Lemma for hidden is hidden
# Lemma for assets is asset
# Lemma for on is on
# Lemma for the is the
# Lemma for ground is ground
# Lemma for . is .
# Lemma for working is working
# Lemma for feverishly is feverishly
# Lemma for to is to
# Lemma for stem is stem
# Lemma for the is the
# Lemma for tide is tide
# Lemma for of is of
# Lemma for the is the
# Lemma for war is war
# Lemma for . is .
# Lemma for who is who
# Lemma for are is are
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for were is were
# Lemma for removed is removed
# Lemma for from is from
# Lemma for power is power
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for by is by
# Lemma for us.led is us.led
# Lemma for forces is force
# Lemma for in is in
# Lemma for . is .
# Lemma for but is but
# Lemma for the is the
# Lemma for group is group
# Lemma for has is ha
# Lemma for gradually is gradually
# Lemma for regained is regained
# Lemma for strength is strength
# Lemma for since is since
# Lemma for and is and
# Lemma for is is is
# Lemma for seizing is seizing
# Lemma for territory is territory
# Lemma for again is again
# Lemma for . is .
# Lemma for as is a
# Lemma for the is the
# Lemma for us is u
# Lemma for prepares is prepares
# Lemma for to is to
# Lemma for complete is complete
# Lemma for its is it
# Lemma for withdrawal is withdrawal
# Lemma for by is by
# Lemma for september is september
# Lemma for . is .
# Lemma for after is after
# Lemma for two is two
# Lemma for decades is decade
# Lemma for of is of
# Lemma for war is war
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for are is are
# Lemma for overrunning is overrunning
# Lemma for afghan is afghan
# Lemma for military is military
# Lemma for outposts is outpost
# Lemma for . is .
# Lemma for town is town
# Lemma for and is and
# Lemma for villages is village
# Lemma for and is and
# Lemma for surrounding is surrounding
# Lemma for major is major
# Lemma for cities is city
# Lemma for . is .
# Lemma for fuelling is fuelling
# Lemma for fears is fear
# Lemma for once is once
# Lemma for again is again
# Lemma for that is that
# Lemma for they is they
# Lemma for could is could
# Lemma for topple is topple
# Lemma for the is the
# Lemma for government is government
# Lemma for . is .
# Lemma for the is the
# Lemma for group is group
# Lemma for entered is entered
# Lemma for direct is direct
# Lemma for talks is talk
# Lemma for with is with
# Lemma for the is the
# Lemma for us is u
# Lemma for back is back
# Lemma for in is in
# Lemma for . is .
# Lemma for and is and
# Lemma for in is in
# Lemma for february is february
# Lemma for the is the
# Lemma for two is two
# Lemma for sides is side
# Lemma for struck is struck
# Lemma for a is a
# Lemma for peace is peace
# Lemma for deal is deal
# Lemma for in is in
# Lemma for doha is doha
# Lemma for that is that
# Lemma for committed is committed
# Lemma for the is the
# Lemma for us is u
# Lemma for to is to
# Lemma for withdrawal is withdrawal
# Lemma for and is and
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for to is to
# Lemma for preventing is preventing
# Lemma for attacks is attack
# Lemma for on is on
# Lemma for us is u
# Lemma for forces is force
# Lemma for . is .
# Lemma for other is other
# Lemma for promises is promise
# Lemma for included is included
# Lemma for not is not
# Lemma for allowing is allowing
# Lemma for al.qaeda is al.qaeda
# Lemma for or is or
# Lemma for other is other
# Lemma for militants is militant
# Lemma for to is to
# Lemma for operate is operate
# Lemma for in is in
# Lemma for areas is area
# Lemma for it is it
# Lemma for controlled is controlled
# Lemma for and is and
# Lemma for proceeding is proceeding
# Lemma for with is with
# Lemma for national is national
# Lemma for peace is peace
# Lemma for talks is talk
# Lemma for . is .
# Lemma for but is but
# Lemma for in is in
# Lemma for the is the
# Lemma for year is year
# Lemma for that is that
# Lemma for followed is followed
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for continued is continued
# Lemma for to is to
# Lemma for target is target
# Lemma for afghan is afghan
# Lemma for security is security
# Lemma for forces is force
# Lemma for and is and
# Lemma for civilians is civilian
# Lemma for . is .
# Lemma for now is now
# Lemma for . is .
# Lemma for as is a
# Lemma for the is the
# Lemma for us is u
# Lemma for prepares is prepares
# Lemma for to is to
# Lemma for leave is leave
# Lemma for . is .
# Lemma for the is the
# Lemma for group is group
# Lemma for is is is
# Lemma for resurgent is resurgent
# Lemma for and is and
# Lemma for advancing is advancing
# Lemma for rapidly is rapidly
# Lemma for across is across
# Lemma for the is the
# Lemma for country is country
# Lemma for . is .
# Lemma for rise is rise
# Lemma for to is to
# Lemma for power is power
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for . is .
# Lemma for or.students is or.students
# Lemma for . is .
# Lemma for in is in
# Lemma for the is the
# Lemma for pashto is pashto
# Lemma for language is language
# Lemma for . is .
# Lemma for emerged is emerged
# Lemma for in is in
# Lemma for the is the
# Lemma for early is early
# Lemma for s is s
# Lemma for in is in
# Lemma for northern is northern
# Lemma for pakistan is pakistan
# Lemma for following is following
# Lemma for the is the
# Lemma for withdrawal is withdrawal
# Lemma for of is of
# Lemma for soviet is soviet
# Lemma for troops is troop
# Lemma for from is from
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for it is it
# Lemma for is is is
# Lemma for believed is believed
# Lemma for that is that
# Lemma for the is the
# Lemma for predominantly is predominantly
# Lemma for pashtun is pashtun
# Lemma for movement is movement
# Lemma for first is first
# Lemma for appeared is appeared
# Lemma for in is in
# Lemma for religious is religious
# Lemma for seminaries is seminary
# Lemma for . is .
# Lemma for mostly is mostly
# Lemma for paid is paid
# Lemma for for is for
# Lemma for by is by
# Lemma for money is money
# Lemma for from is from
# Lemma for saudi is saudi
# Lemma for arabia is arabia
# Lemma for . is .
# Lemma for which is which
# Lemma for preached is preached
# Lemma for a is a
# Lemma for hardline is hardline
# Lemma for form is form
# Lemma for of is of
# Lemma for sunni is sunni
# Lemma for islam is islam
# Lemma for . is .
# Lemma for the is the
# Lemma for promise is promise
# Lemma for made is made
# Lemma for by is by
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for . is .
# Lemma for in is in
# Lemma for pashtun is pashtun
# Lemma for areas is area
# Lemma for straddling is straddling
# Lemma for pakistan is pakistan
# Lemma for and is and
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for was is wa
# Lemma for to is to
# Lemma for restore is restore
# Lemma for peace is peace
# Lemma for and is and
# Lemma for security is security
# Lemma for and is and
# Lemma for enforce is enforce
# Lemma for their is their
# Lemma for own is own
# Lemma for austere is austere
# Lemma for version is version
# Lemma for of is of
# Lemma for sharia is sharia
# Lemma for . is .
# Lemma for or is or
# Lemma for islamic is islamic
# Lemma for law is law
# Lemma for . is .
# Lemma for once is once
# Lemma for in is in
# Lemma for power is power
# Lemma for . is .
# Lemma for from is from
# Lemma for south.western is south.western
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for quickly is quickly
# Lemma for extended is extended
# Lemma for their is their
# Lemma for influence is influence
# Lemma for . is .
# Lemma for in is in
# Lemma for september is september
# Lemma for they is they
# Lemma for captured is captured
# Lemma for the is the
# Lemma for province is province
# Lemma for of is of
# Lemma for herat is herat
# Lemma for . is .
# Lemma for bordering is bordering
# Lemma for iran is iran
# Lemma for . is .
# Lemma for and is and
# Lemma for exactly is exactly
# Lemma for one is one
# Lemma for year is year
# Lemma for later is later
# Lemma for they is they
# Lemma for captured is captured
# Lemma for the is the
# Lemma for afghan is afghan
# Lemma for capital is capital
# Lemma for . is .
# Lemma for kabul is kabul
# Lemma for . is .
# Lemma for overthrowing is overthrowing
# Lemma for the is the
# Lemma for regime is regime
# Lemma for of is of
# Lemma for president is president
# Lemma for burhanuddin is burhanuddin
# Lemma for rabbani is rabbani
# Lemma for . is .
# Lemma for one is one
# Lemma for of is of
# Lemma for the is the
# Lemma for founding is founding
# Lemma for fathers is father
# Lemma for of is of
# Lemma for the is the
# Lemma for afghan is afghan
# Lemma for mujahideen is mujahideen
# Lemma for that is that
# Lemma for resisted is resisted
# Lemma for the is the
# Lemma for soviet is soviet
# Lemma for occupation is occupation
# Lemma for . is .
# Lemma for by is by
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for were is were
# Lemma for in is in
# Lemma for control is control
# Lemma for of is of
# Lemma for almost is almost
# Lemma for . is .
# Lemma for of is of
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for afghans is afghan
# Lemma for . is .
# Lemma for weary is weary
# Lemma for of is of
# Lemma for the is the
# Lemma for mujahideen.s is mujahideen.s
# Lemma for excesses is excess
# Lemma for and is and
# Lemma for infighting is infighting
# Lemma for after is after
# Lemma for the is the
# Lemma for soviets is soviet
# Lemma for were is were
# Lemma for driven is driven
# Lemma for out is out
# Lemma for . is .
# Lemma for generally is generally
# Lemma for welcomed is welcomed
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for when is when
# Lemma for they is they
# Lemma for first is first
# Lemma for appeared is appeared
# Lemma for on is on
# Lemma for the is the
# Lemma for scene is scene
# Lemma for . is .
# Lemma for their is their
# Lemma for early is early
# Lemma for popularity is popularity
# Lemma for was is wa
# Lemma for largely is largely
# Lemma for due is due
# Lemma for to is to
# Lemma for their is their
# Lemma for success is success
# Lemma for in is in
# Lemma for stamping is stamping
# Lemma for out is out
# Lemma for corruption is corruption
# Lemma for . is .
# Lemma for curbing is curbing
# Lemma for lawlessness is lawlessness
# Lemma for and is and
# Lemma for making is making
# Lemma for the is the
# Lemma for roads is road
# Lemma for and is and
# Lemma for the is the
# Lemma for areas is area
# Lemma for under is under
# Lemma for their is their
# Lemma for control is control
# Lemma for safe is safe
# Lemma for for is for
# Lemma for commerce is commerce
# Lemma for to is to
# Lemma for flourish is flourish
# Lemma for . is .
# Lemma for but is but
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for also is also
# Lemma for introduced is introduced
# Lemma for or is or
# Lemma for supported is supported
# Lemma for punishments is punishment
# Lemma for in is in
# Lemma for line is line
# Lemma for with is with
# Lemma for their is their
# Lemma for strict is strict
# Lemma for interpretation is interpretation
# Lemma for of is of
# Lemma for sharia is sharia
# Lemma for law is law
# Lemma for . is .
# Lemma for such is such
# Lemma for as is a
# Lemma for public is public
# Lemma for executions is execution
# Lemma for of is of
# Lemma for convicted is convicted
# Lemma for murderers is murderer
# Lemma for and is and
# Lemma for adulterers is adulterer
# Lemma for . is .
# Lemma for and is and
# Lemma for amputations is amputation
# Lemma for for is for
# Lemma for those is those
# Lemma for found is found
# Lemma for guilty is guilty
# Lemma for of is of
# Lemma for theft is theft
# Lemma for . is .
# Lemma for men is men
# Lemma for were is were
# Lemma for required is required
# Lemma for to is to
# Lemma for grow is grow
# Lemma for beards is beard
# Lemma for and is and
# Lemma for women is woman
# Lemma for had is had
# Lemma for to is to
# Lemma for wear is wear
# Lemma for the is the
# Lemma for all.covering is all.covering
# Lemma for burka is burka
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for also is also
# Lemma for banned is banned
# Lemma for television is television
# Lemma for . is .
# Lemma for music is music
# Lemma for and is and
# Lemma for cinema is cinema
# Lemma for . is .
# Lemma for and is and
# Lemma for disapproved is disapproved
# Lemma for of is of
# Lemma for girls is girl
# Lemma for aged is aged
# Lemma for and is and
# Lemma for over is over
# Lemma for going is going
# Lemma for to is to
# Lemma for school is school
# Lemma for . is .
# Lemma for they is they
# Lemma for were is were
# Lemma for accused is accused
# Lemma for of is of
# Lemma for various is various
# Lemma for human is human
# Lemma for rights is right
# Lemma for and is and
# Lemma for cultural is cultural
# Lemma for abuses is abuse
# Lemma for . is .
# Lemma for one is one
# Lemma for notorious is notorious
# Lemma for example is example
# Lemma for was is wa
# Lemma for in is in
# Lemma for . is .
# Lemma for when is when
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for went is went
# Lemma for ahead is ahead
# Lemma for with is with
# Lemma for the is the
# Lemma for destruction is destruction
# Lemma for of is of
# Lemma for the is the
# Lemma for famous is famous
# Lemma for bamiyan is bamiyan
# Lemma for buddha is buddha
# Lemma for statues is statue
# Lemma for in is in
# Lemma for central is central
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for despite is despite
# Lemma for international is international
# Lemma for outrage is outrage
# Lemma for . is .
# Lemma for pakistan is pakistan
# Lemma for has is ha
# Lemma for repeatedly is repeatedly
# Lemma for denied is denied
# Lemma for that is that
# Lemma for it is it
# Lemma for was is wa
# Lemma for the is the
# Lemma for architect is architect
# Lemma for of is of
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for enterprise is enterprise
# Lemma for . is .
# Lemma for but is but
# Lemma for there is there
# Lemma for is is is
# Lemma for little is little
# Lemma for doubt is doubt
# Lemma for that is that
# Lemma for many is many
# Lemma for afghans is afghan
# Lemma for who is who
# Lemma for initially is initially
# Lemma for joined is joined
# Lemma for the is the
# Lemma for movement is movement
# Lemma for were is were
# Lemma for educated is educated
# Lemma for in is in
# Lemma for madrassas is madrassas
# Lemma for .religious is .religious
# Lemma for schools is school
# Lemma for . is .
# Lemma for in is in
# Lemma for pakistan is pakistan
# Lemma for . is .
# Lemma for pakistan is pakistan
# Lemma for was is wa
# Lemma for also is also
# Lemma for one is one
# Lemma for of is of
# Lemma for only is only
# Lemma for three is three
# Lemma for countries is country
# Lemma for . is .
# Lemma for along is along
# Lemma for with is with
# Lemma for saudi is saudi
# Lemma for arabia is arabia
# Lemma for and is and
# Lemma for the is the
# Lemma for united is united
# Lemma for arab is arab
# Lemma for emirates is emirate
# Lemma for .uae is .uae
# Lemma for . is .
# Lemma for which is which
# Lemma for recognised is recognised
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for when is when
# Lemma for they is they
# Lemma for were is were
# Lemma for in is in
# Lemma for power is power
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for it is it
# Lemma for was is wa
# Lemma for also is also
# Lemma for the is the
# Lemma for last is last
# Lemma for country is country
# Lemma for to is to
# Lemma for break is break
# Lemma for diplomatic is diplomatic
# Lemma for ties is tie
# Lemma for with is with
# Lemma for the is the
# Lemma for group is group
# Lemma for . is .
# Lemma for at is at
# Lemma for one is one
# Lemma for point is point
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for threatened is threatened
# Lemma for to is to
# Lemma for destabilise is destabilise
# Lemma for pakistan is pakistan
# Lemma for from is from
# Lemma for areas is area
# Lemma for they is they
# Lemma for controlled is controlled
# Lemma for in is in
# Lemma for the is the
# Lemma for north.west is north.west
# Lemma for . is .
# Lemma for one is one
# Lemma for of is of
# Lemma for the is the
# Lemma for most is most
# Lemma for high.profile is high.profile
# Lemma for and is and
# Lemma for internationally is internationally
# Lemma for condemned is condemned
# Lemma for of is of
# Lemma for all is all
# Lemma for pakistani is pakistani
# Lemma for taliban is taliban
# Lemma for attacks is attack
# Lemma for took is took
# Lemma for place is place
# Lemma for in is in
# Lemma for october is october
# Lemma for . is .
# Lemma for when is when
# Lemma for schoolgirl is schoolgirl
# Lemma for malala is malala
# Lemma for yousafzai is yousafzai
# Lemma for was is wa
# Lemma for shot is shot
# Lemma for on is on
# Lemma for her is her
# Lemma for way is way
# Lemma for home is home
# Lemma for in is in
# Lemma for the is the
# Lemma for town is town
# Lemma for of is of
# Lemma for mingora is mingora
# Lemma for . is .
# Lemma for a is a
# Lemma for major is major
# Lemma for military is military
# Lemma for offensive is offensive
# Lemma for two is two
# Lemma for years is year
# Lemma for later is later
# Lemma for following is following
# Lemma for the is the
# Lemma for peshawar is peshawar
# Lemma for school is school
# Lemma for massacre is massacre
# Lemma for greatly is greatly
# Lemma for reduced is reduced
# Lemma for the is the
# Lemma for group.s is group.s
# Lemma for influence is influence
# Lemma for in is in
# Lemma for pakistan is pakistan
# Lemma for though is though
# Lemma for . is .
# Lemma for at is at
# Lemma for least is least
# Lemma for three is three
# Lemma for key is key
# Lemma for figures is figure
# Lemma for of is of
# Lemma for the is the
# Lemma for pakistani is pakistani
# Lemma for taliban is taliban
# Lemma for had is had
# Lemma for been is been
# Lemma for killed is killed
# Lemma for in is in
# Lemma for us is u
# Lemma for drone is drone
# Lemma for strikes is strike
# Lemma for in is in
# Lemma for . is .
# Lemma for including is including
# Lemma for the is the
# Lemma for group.s is group.s
# Lemma for leader is leader
# Lemma for . is .
# Lemma for hakimullah is hakimullah
# Lemma for mehsud is mehsud
# Lemma for . is .
# Lemma for al.qaeda.sanctuary is al.qaeda.sanctuary
# Lemma for . is .
# Lemma for the is the
# Lemma for attention is attention
# Lemma for of is of
# Lemma for the is the
# Lemma for world is world
# Lemma for was is wa
# Lemma for drawn is drawn
# Lemma for to is to
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for in is in
# Lemma for the is the
# Lemma for wake is wake
# Lemma for of is of
# Lemma for the is the
# Lemma for september is september
# Lemma for world is world
# Lemma for trade is trade
# Lemma for center is center
# Lemma for attacks is attack
# Lemma for in is in
# Lemma for new is new
# Lemma for york is york
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for were is were
# Lemma for accused is accused
# Lemma for of is of
# Lemma for providing is providing
# Lemma for a is a
# Lemma for sanctuary is sanctuary
# Lemma for for is for
# Lemma for the is the
# Lemma for prime is prime
# Lemma for suspects is suspect
# Lemma for . is .
# Lemma for osama is osama
# Lemma for bin is bin
# Lemma for laden is laden
# Lemma for and is and
# Lemma for his is his
# Lemma for al.qaeda is al.qaeda
# Lemma for movement is movement
# Lemma for . is .
# Lemma for on is on
# Lemma for october is october
# Lemma for . is .
# Lemma for a is a
# Lemma for us.led is us.led
# Lemma for military is military
# Lemma for coalition is coalition
# Lemma for launched is launched
# Lemma for attacks is attack
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for and is and
# Lemma for by is by
# Lemma for the is the
# Lemma for first is first
# Lemma for week is week
# Lemma for of is of
# Lemma for december is december
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for regime is regime
# Lemma for had is had
# Lemma for collapsed is collapsed
# Lemma for . is .
# Lemma for the is the
# Lemma for group.s is group.s
# Lemma for then.leader is then.leader
# Lemma for . is .
# Lemma for mullah is mullah
# Lemma for mohammad is mohammad
# Lemma for omar is omar
# Lemma for . is .
# Lemma for and is and
# Lemma for other is other
# Lemma for senior is senior
# Lemma for figures is figure
# Lemma for . is .
# Lemma for including is including
# Lemma for bin is bin
# Lemma for laden is laden
# Lemma for . is .
# Lemma for evaded is evaded
# Lemma for capture is capture
# Lemma for despite is despite
# Lemma for one is one
# Lemma for of is of
# Lemma for the is the
# Lemma for largest is largest
# Lemma for manhunts is manhunt
# Lemma for in is in
# Lemma for the is the
# Lemma for world is world
# Lemma for . is .
# Lemma for many is many
# Lemma for senior is senior
# Lemma for taliban is taliban
# Lemma for leaders is leader
# Lemma for reportedly is reportedly
# Lemma for took is took
# Lemma for refuge is refuge
# Lemma for in is in
# Lemma for the is the
# Lemma for pakistani is pakistani
# Lemma for city is city
# Lemma for of is of
# Lemma for quetta is quetta
# Lemma for . is .
# Lemma for from is from
# Lemma for where is where
# Lemma for they is they
# Lemma for guided is guided
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for . is .
# Lemma for but is but
# Lemma for the is the
# Lemma for existence is existence
# Lemma for of is of
# Lemma for what is what
# Lemma for was is wa
# Lemma for dubbed is dubbed
# Lemma for the.quetta is the.quetta
# Lemma for shura is shura
# Lemma for . is .
# Lemma for was is wa
# Lemma for denied is denied
# Lemma for by is by
# Lemma for islamabad is islamabad
# Lemma for . is .
# Lemma for despite is despite
# Lemma for ever is ever
# Lemma for higher is higher
# Lemma for numbers is number
# Lemma for of is of
# Lemma for foreign is foreign
# Lemma for troops is troop
# Lemma for . is .
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for gradually is gradually
# Lemma for regained is regained
# Lemma for and is and
# Lemma for then is then
# Lemma for extended is extended
# Lemma for their is their
# Lemma for influence is influence
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for rendering is rendering
# Lemma for vast is vast
# Lemma for tracts is tract
# Lemma for of is of
# Lemma for of is of
# Lemma for the is the
# Lemma for country is country
# Lemma for insecure is insecure
# Lemma for . is .
# Lemma for and is and
# Lemma for violence is violence
# Lemma for in is in
# Lemma for the is the
# Lemma for country is country
# Lemma for returned is returned
# Lemma for to is to
# Lemma for levels is level
# Lemma for not is not
# Lemma for seen is seen
# Lemma for since is since
# Lemma for . is .
# Lemma for there is there
# Lemma for were is were
# Lemma for numerous is numerous
# Lemma for taliban is taliban
# Lemma for attacks is attack
# Lemma for on is on
# Lemma for kabul is kabul
# Lemma for and is and
# Lemma for . is .
# Lemma for in is in
# Lemma for september is september
# Lemma for . is .
# Lemma for the is the
# Lemma for group is group
# Lemma for carried is carried
# Lemma for out is out
# Lemma for a is a
# Lemma for high.profile is high.profile
# Lemma for raid is raid
# Lemma for on is on
# Lemma for nato.s is nato.s
# Lemma for camp is camp
# Lemma for bastion is bastion
# Lemma for base is base
# Lemma for . is .
# Lemma for hopes is hope
# Lemma for of is of
# Lemma for a is a
# Lemma for negotiated is negotiated
# Lemma for peace is peace
# Lemma for were is were
# Lemma for raised is raised
# Lemma for in is in
# Lemma for . is .
# Lemma for when is when
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for announced is announced
# Lemma for plans is plan
# Lemma for to is to
# Lemma for open is open
# Lemma for an is an
# Lemma for office is office
# Lemma for in is in
# Lemma for qatar is qatar
# Lemma for . is .
# Lemma for but is but
# Lemma for mistrust is mistrust
# Lemma for on is on
# Lemma for all is all
# Lemma for sides is side
# Lemma for remained is remained
# Lemma for high is high
# Lemma for and is and
# Lemma for the is the
# Lemma for violence is violence
# Lemma for went is went
# Lemma for on is on
# Lemma for . is .
# Lemma for in is in
# Lemma for august is august
# Lemma for . is .
# Lemma for the is the
# ...
# Lemma for who is who
# Lemma for are is are
# Lemma for eligible is eligible
# Lemma for . is .
# Lemma for but is but
# Lemma for this is this
# Lemma for still is still
# Lemma for does is doe
# Lemma for not is not
# Lemma for include is include
# Lemma for any is any
# Lemma for interpreters is interpreter
# Lemma for who is who
# Lemma for were is were
# Lemma for dismissed.unless is dismissed.unless
# Lemma for in is in
# Lemma for exceptional is exceptional
# Lemma for circumstances.we is circumstances.we
# Lemma for owe is owe
# Lemma for a is a
# Lemma for huge is huge
# Lemma for debt is debt
# Lemma for of is of
# Lemma for gratitude is gratitude
# Lemma for to is to
# Lemma for interpreters is interpreter
# Lemma for who is who
# Lemma for risked is risked
# Lemma for their is their
# Lemma for lives is life
# Lemma for working is working
# Lemma for alongside is alongside
# Lemma for uk is uk
# Lemma for forces is force
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for . is .
# Lemma for a is a
# Lemma for spokesperson is spokesperson
# Lemma for for is for
# Lemma for the is the
# Lemma for ministry is ministry
# Lemma for of is of
# Lemma for defence is defence
# Lemma for told is told
# Lemma for the is the
# Lemma for bbc.nobody.s is bbc.nobody.s
# Lemma for life is life
# Lemma for should is should
# Lemma for be is be
# Lemma for put is put
# Lemma for at is at
# Lemma for risk is risk
# Lemma for because is because
# Lemma for they is they
# Lemma for supported is supported
# Lemma for the is the
# Lemma for uk is uk
# Lemma for government is government
# Lemma for to is to
# Lemma for bring is bring
# Lemma for peace is peace
# Lemma for and is and
# Lemma for stability is stability
# Lemma for . is .
# Lemma for we is we
# Lemma for are is are
# Lemma for the is the
# Lemma for only is only
# Lemma for nation is nation
# Lemma for with is with
# Lemma for a is a
# Lemma for permanent is permanent
# Lemma for expert is expert
# Lemma for team is team
# Lemma for based is based
# Lemma for in is in
# Lemma for kabul is kabul
# Lemma for to is to
# Lemma for investigate is investigate
# Lemma for claims is claim
# Lemma for from is from
# Lemma for courageous is courageous
# Lemma for local is local
# Lemma for staff is staff
# Lemma for who is who
# Lemma for are is are
# Lemma for threatened is threatened
# Lemma for as is a
# Lemma for a is a
# Lemma for result is result
# Lemma for of is of
# Lemma for their is their
# Lemma for work is work
# Lemma for with is with
# Lemma for the is the
# Lemma for uk is uk
# Lemma for . is .
# Lemma for so is so
# Lemma for far is far
# Lemma for . is .
# Lemma for some is some
# Lemma for . is .
# Lemma for interpreters is interpreter
# Lemma for have is have
# Lemma for been is been
# Lemma for able is able
# Lemma for to is to
# Lemma for relocate is relocate
# Lemma for to is to
# Lemma for the is the
# Lemma for uk is uk
# Lemma for . is .
# Lemma for from is from
# Lemma for a is a
# Lemma for total is total
# Lemma for of is of
# Lemma for . is .
# Lemma for interpreters is interpreter
# Lemma for and is and
# Lemma for other is other
# Lemma for staff is staff
# Lemma for employed is employed
# Lemma for by is by
# Lemma for the is the
# Lemma for uk is uk
# Lemma for military is military
# Lemma for . is .
# Lemma for one is one
# Lemma for of is of
# Lemma for them is them
# Lemma for is is is
# Lemma for eddie is eddie
# Lemma for idrees is idrees
# Lemma for .not is .not
# Lemma for his is his
# Lemma for real is real
# Lemma for name is name
# Lemma for . is .
# Lemma for a is a
# Lemma for former is former
# Lemma for sas is sa
# Lemma for interpreter is interpreter
# Lemma for who is who
# Lemma for took is took
# Lemma for part is part
# Lemma for in is in
# Lemma for hundreds is hundred
# Lemma for of is of
# Lemma for missions is mission
# Lemma for including is including
# Lemma for parachute is parachute
# Lemma for jumps is jump
# Lemma for and is and
# Lemma for a is a
# Lemma for break.in is break.in
# Lemma for to is to
# Lemma for a is a
# Lemma for taliban is taliban
# Lemma for prison is prison
# Lemma for . is .
# Lemma for experiences is experience
# Lemma for he is he
# Lemma for has is ha
# Lemma for documented is documented
# Lemma for in is in
# Lemma for a is a
# Lemma for book is book
# Lemma for . is .
# Lemma for of is of
# Lemma for friends is friend
# Lemma for who is who
# Lemma for worked is worked
# Lemma for with is with
# Lemma for us is u
# Lemma for and is and
# Lemma for british is british
# Lemma for troops is troop
# Lemma for only is only
# Lemma for he is he
# Lemma for and is and
# Lemma for a is a
# Lemma for friend is friend
# Lemma for also is also
# Lemma for now is now
# Lemma for in is in
# Lemma for the is the
# Lemma for uk is uk
# Lemma for survived is survived
# Lemma for . is .
# Lemma for all is all
# Lemma for the is the
# Lemma for others is others
# Lemma for were is were
# Lemma for either is either
# Lemma for killed is killed
# Lemma for in is in
# Lemma for action is action
# Lemma for or is or
# Lemma for later is later
# Lemma for murdered is murdered
# Lemma for by is by
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for . is .
# Lemma for mr is mr
# Lemma for idrees is idrees
# Lemma for says is say
# Lemma for he is he
# Lemma for also is also
# Lemma for fears is fear
# Lemma for for is for
# Lemma for interpreters is interpreter
# Lemma for who is who
# Lemma for have is have
# Lemma for worked is worked
# Lemma for on is on
# Lemma for military is military
# Lemma for operations is operation
# Lemma for and is and
# Lemma for remain is remain
# Lemma for in is in
# Lemma for afghanistan is afghanistan
# Lemma for after is after
# Lemma for the is the
# Lemma for international is international
# Lemma for pullout.when is pullout.when
# Lemma for the is the
# Lemma for british is british
# Lemma for pull is pull
# Lemma for out is out
# Lemma for of is of
# Lemma for afghanistan is afghanistan
# Lemma for it is it
# Lemma for will is will
# Lemma for just is just
# Lemma for let is let
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for target is target
# Lemma for them is them
# Lemma for easily is easily
# Lemma for . is .
# Lemma for he is he
# Lemma for said is said
# Lemma for . is .
# Lemma for even is even
# Lemma for those is those
# Lemma for who is who
# Lemma for are is are
# Lemma for eligible is eligible
# Lemma for for is for
# Lemma for the is the
# Lemma for scheme is scheme
# Lemma for face is face
# Lemma for an is an
# Lemma for application is application
# Lemma for process is process
# Lemma for that is that
# Lemma for can is can
# Lemma for last is last
# Lemma for for is for
# Lemma for up is up
# Lemma for to is to
# Lemma for months is month
# Lemma for . is .
# Lemma for a is a
# Lemma for delay is delay
# Lemma for that is that
# Lemma for mr is mr
# Lemma for idrees is idrees
# Lemma for says is say
# Lemma for could is could
# Lemma for put is put
# Lemma for lives is life
# Lemma for at is at
# Lemma for risk.the is risk.the
# Lemma for day is day
# Lemma for when is when
# Lemma for british is british
# Lemma for forces is force
# Lemma for leave is leave
# Lemma for it is it
# Lemma for is is is
# Lemma for the is the
# Lemma for day is day
# Lemma for you is you
# Lemma for will is will
# Lemma for see is see
# Lemma for a is a
# Lemma for surge is surge
# Lemma for in is in
# Lemma for violence is violence
# Lemma for . is .
# Lemma for once is once
# Lemma for they is they
# Lemma for leave is leave
# Lemma for . is .
# Lemma for those is those
# Lemma for areas is area
# Lemma for that is that
# Lemma for used is used
# Lemma for to is to
# Lemma for be is be
# Lemma for safe is safe
# Lemma for . is .
# Lemma for those is those
# Lemma for provinces is province
# Lemma for . is .
# Lemma for won.t is won.t
# Lemma for be is be
# Lemma for safe is safe
# Lemma for any is any
# Lemma for more is more
# Lemma for . is .
# Lemma for and is and
# Lemma for these is these
# Lemma for interpreters is interpreter
# Lemma for are is are
# Lemma for not is not
# Lemma for going is going
# Lemma for to is to
# Lemma for be is be
# Lemma for forgotten is forgotten
# Lemma for by is by
# Lemma for the is the
# Lemma for taliban.still is taliban.still
# Lemma for waiting is waiting
# Lemma for . is .
# Lemma for col is col
# Lemma for diggins is diggins
# Lemma for has is ha
# Lemma for called is called
# Lemma for for is for
# Lemma for an.emergency is an.emergency
# Lemma for plan is plan
# Lemma for . is .
# Lemma for to is to
# Lemma for relocate is relocate
# Lemma for interpreters is interpreter
# Lemma for as is a
# Lemma for soon is soon
# Lemma for as is a
# Lemma for possible.what is possible.what
# Lemma for really is really
# Lemma for worries is worry
# Lemma for me is me
# Lemma for is is is
# Lemma for the is the
# Lemma for scale is scale
# Lemma for and is and
# Lemma for pace is pace
# Lemma for to is to
# Lemma for get is get
# Lemma for the is the
# Lemma for people is people
# Lemma for who is who
# Lemma for deserve is deserve
# Lemma for to is to
# Lemma for come is come
# Lemma for to is to
# Lemma for this is this
# Lemma for country is country
# Lemma for given is given
# Lemma for how is how
# Lemma for the is the
# Lemma for situation is situation
# Lemma for is is is
# Lemma for worsening is worsening
# Lemma for . is .
# Lemma for he is he
# Lemma for said.it.s is said.it.s
# Lemma for taking is taking
# Lemma for to is to
# Lemma for months is month
# Lemma for to is to
# Lemma for process is process
# Lemma for paperwork is paperwork
# Lemma for . is .
# Lemma for we is we
# Lemma for don.t is don.t
# Lemma for have is have
# Lemma for that is that
# Lemma for much is much
# Lemma for time is time
# Lemma for . is .
# Lemma for the is the
# Lemma for ministry is ministry
# Lemma for of is of
# Lemma for defence is defence
# Lemma for says is say
# Lemma for it is it
# Lemma for is is is
# Lemma for currently is currently
# Lemma for looking is looking
# Lemma for at is at
# Lemma for the is the
# Lemma for cases is case
# Lemma for of is of
# Lemma for former is former
# Lemma for interpreters is interpreter
# Lemma for . is .
# Lemma for among is among
# Lemma for them is them
# Lemma for is.amir is is.amir
# Lemma for . is .
# Lemma for who is who
# Lemma for served is served
# Lemma for for is for
# Lemma for two is two
# Lemma for years is year
# Lemma for on is on
# Lemma for the is the
# Lemma for front is front
# Lemma for line is line
# Lemma for with is with
# Lemma for british is british
# Lemma for troops is troop
# Lemma for in is in
# Lemma for helmand is helmand
# Lemma for where is where
# Lemma for they is they
# Lemma for came is came
# Lemma for under is under
# Lemma for regular is regular
# Lemma for attack is attack
# Lemma for from is from
# Lemma for the is the
# Lemma for taliban is taliban
# Lemma for . is .
# Lemma for since is since
# Lemma for resigning is resigning
# Lemma for in is in
# Lemma for . is .
# Lemma for he is he
# Lemma for says is say
# Lemma for he is he
# Lemma for has is ha
# Lemma for faced is faced
# Lemma for intimidation is intimidation
# Lemma for over is over
# Lemma for his is his
# Lemma for work is work
# Lemma for with is with
# Lemma for the is the
# Lemma for british is british
# Lemma for . is .
# Lemma for he is he
# Lemma for hasn.t is hasn.t
# Lemma for been is been
# Lemma for able is able
# Lemma for to is to
# Lemma for see is see
# Lemma for his is his
# Lemma for family is family
# Lemma for who is who
# Lemma for live is live
# Lemma for in is in
# Lemma for taliban.controlled is taliban.controlled
# Lemma for territory is territory
# Lemma for in is in
# Lemma for logar is logar
# Lemma for province is province
# Lemma for . is .
# Lemma for just is just
# Lemma for outside is outside
# Lemma for kabul is kabul
# Lemma for . is .
# Lemma for having is having
# Lemma for been is been
# Lemma for rejected is rejected
# Lemma for twice is twice
# Lemma for . is .
# Lemma for amir is amir
# Lemma for is is is
# Lemma for hopeful is hopeful
# Lemma for his is his
# Lemma for third is third
# Lemma for application is application
# Lemma for will is will
# Lemma for be is be
# Lemma for successful.i is successful.i
# Lemma for am is am
# Lemma for waiting is waiting
# Lemma for to is to
# Lemma for hear is hear
# Lemma for good is good
# Lemma for news is news
# Lemma for . is .
# Lemma for he is he
# Lemma for said is said
# Lemma for . is .
# Lemma for but is but
# Lemma for he is he
# Lemma for has is ha
# Lemma for felt.dread is felt.dread
# Lemma for . is .
# Lemma for since is since
# Lemma for hearing is hearing
# Lemma for the is the
# Lemma for news is news
# Lemma for the is the
# Lemma for foreign is foreign
# Lemma for troops is troop
# Lemma for would is would
# Lemma for withdraw.that is withdraw.that
# Lemma for is is is
# Lemma for going is going
# Lemma for to is to
# Lemma for cause is cause
# Lemma for more is more
# Lemma for of is of
# Lemma for a is a
# Lemma for problem is problem
# Lemma for for is for
# Lemma for us is u
# Lemma for . is .
# Lemma for i is i
# Lemma for feel is feel
# Lemma for a is a
# Lemma for lot is lot
# Lemma for of is of
# Lemma for risk is risk
# Lemma for these is these
# Lemma for days is day
# Lemma for . is .
# Lemma for if is if
# Lemma for you is you
# Lemma for served is served
# Lemma for as is a
# Lemma for an is an
# Lemma for interpreter is interpreter
# Lemma for who is who
# Lemma for worked is worked
# Lemma for with is with
# Lemma for the is the
# Lemma for british is british
# Lemma for you is you
# Lemma for are is are
# Lemma for staying is staying
# Lemma for at is at
# Lemma for home is home
# Lemma for . is .
# Lemma for the is the
# Lemma for uk is uk
# Lemma for is is is
# Lemma for not is not
# Lemma for the is the
# Lemma for only is only
# Lemma for country is country
# Lemma for working is working
# Lemma for on is on
# Lemma for schemes is scheme
# Lemma for to is to
# Lemma for help is help
# Lemma for their is their
# Lemma for former is former
# Lemma for afghan is afghan
# Lemma for interpreters is interpreter
# Lemma for . is .
# Lemma for the is the
# Lemma for us is u
# Lemma for has is ha
# Lemma for a is a
# Lemma for special is special
# Lemma for visa is visa
# Lemma for programme is programme
# Lemma for for is for
# Lemma for afghans is afghan
# Lemma for who is who
# Lemma for have is have
# Lemma for worked is worked
# Lemma for with is with
# Lemma for its is it
# Lemma for military is military
# Lemma for . is .
# Lemma for at is at
# Lemma for least is least
# Lemma for . is .
# Lemma for individuals is individual
# Lemma for have is have
# Lemma for been is been
# Lemma for resettled is resettled
# Lemma for through is through
# Lemma for the is the
# Lemma for scheme is scheme
# Lemma for and is and
# Lemma for . is .
# Lemma for are is are
# Lemma for still is still
# Lemma for waiting is waiting
# Lemma for for is for
# Lemma for a is a
# Lemma for result is result
# Lemma for . is .
# Lemma for according is according
# Lemma for to is to
# Lemma for the is the
# Lemma for international is international
# Lemma for refugee is refugee
# Lemma for assistance is assistance
# Lemma for project is project
# Lemma for . is .
# Lemma for germany.s is germany.s
# Lemma for defence is defence
# Lemma for minister is minister
# Lemma for has is ha
# Lemma for said is said
# Lemma for it is it
# Lemma for is is is
# Lemma for her is her
# Lemma for country.s is country.s
# Lemma for duty is duty
# Lemma for to is to
# Lemma for protect is protect
# Lemma for afghan is afghan
# Lemma for staff is staff
# Lemma for when is when
# Lemma for the is the
# Lemma for german is german
# Lemma for contingent is contingent
# Lemma for leaves is leaf
# Lemma for . is .
# Lemma for but is but
# Lemma for for is for
# Lemma for those is those
# Lemma for who is who
# Lemma for have is have
# Lemma for so is so
# Lemma for far is far
# Lemma for not is not
# Lemma for qualified is qualified
# Lemma for for is for
# Lemma for the is the
# Lemma for schemes is scheme
# Lemma for . is .
# Lemma for the is the
# Lemma for future is future
# Lemma for is is is
# Lemma for uncertain.i is uncertain.i
# Lemma for am is am
# Lemma for going is going
# Lemma for to is to
# Lemma for try is try
# Lemma for to is to
# Lemma for make is make
# Lemma for them is them
# Lemma for trust is trust
# Lemma for me is me
# Lemma for and is and
# Lemma for see is see
# Lemma for that is that
# Lemma for my is my
# Lemma for life is life
# Lemma for is is is
# Lemma for at is at
# Lemma for risk is risk
# Lemma for . is .
# Lemma for aj is aj
# Lemma for said is said
# Lemma for after is after
# Lemma for hearing is hearing
# Lemma for his is his
# Lemma for fourth is fourth
# Lemma for application is application
# Lemma for had is had
# Lemma for been is been
# Lemma for rejected.it.s is rejected.it.s
# Lemma for terrible is terrible
# Lemma for . is .
# Lemma for i.m is i.m
# Lemma for still is still
# Lemma for waiting is waiting
# Lemma for . is .
